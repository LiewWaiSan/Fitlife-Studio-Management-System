# %% [markdown]
# <a href="https://colab.research.google.com/github/LiewWaiSan/Fitlife-Studio-Management-System/blob/main/Fitlife_M2_LiewWaiSanGH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1: Build a member list
# Task 2: Build membership plan in Tuple
# Task 3: Build studio branches set
# Task 4: Build weekly timetable
# Task 5: Show the final status

# %%
# ==================================================

# TASK 1 - MEMBERS LIST

# ==================================================

members = [

    {

        "id": "FL-001",

        "name": "Tan Jia Hui",

        "plan": "Basic",

        "branch": "Tampines One",

        "joined": "2025-10-15",

        "expires": "2026-04-15",

        "status": "EXPIRED"

    },

    {

        "id": "FL-002",

        "name": "Rajesh Kumaran",

        "plan": "Premium",

        "branch": "Bukit Timah Plaza",

        "joined": "2026-02-03",

        "expires": "2026-08-03",

        "status": "active"

    },

    {

        "id": "FL-003",

        "name": "Nur Hidayah Binte Rahman",

        "plan": "Plus",

        "branch": "Tampines One",

        "joined": "2025-11-10",

        "expires": "2026-05-10",

        "status": "EXPIRED"

    },

    {

        "id": "FL-004",

        "name": "Marcus Wong",

        "plan": "Basic",

        "branch": "JEM",

        "joined": "2026-04-05",

        "expires": "2026-10-05",

        "status": "active"

    },

    {

        "id": "FL-005",

        "name": "Priya Subramaniam",

        "plan": "Premium",

        "branch": "Bukit Timah Plaza",

        "joined": "2026-01-01",

        "expires": "2026-07-01",

        "status": "active"

    },

    {

        "id": "FL-006",

        "name": "David Chen",

        "plan": "Plus",

        "branch": "JEM",

        "joined": "2026-04-20",

        "expires": "2026-10-20",

        "status": "active"

    }

]

print("Total members loaded :", len(members))

print("First member :", members[0])

print("Third member's name :", members[2]["name"])


# ==================================================

# TASK 2 - PLANS TUPLE

# ==================================================

plans = (

    ("Basic", 88),

    ("Plus", 128),

    ("Premium", 188)

)

print()

print("Plans loaded :", plans)

print("First plan :", plans[0])

print("Last plan's fee :", plans[-1][1])

# Uncomment to see TypeError - tuples are immutable.

# plans[0] = ("Cheaper Basic", 50)


# ==================================================

# TASK 3 - BRANCHES SET

# ==================================================

member_branches = [

    "Tampines One",

    "Bukit Timah Plaza",

    "Tampines One",

    "JEM (Jurong East Mall)",

    "Bukit Timah Plaza",

    "JEM (Jurong East Mall)"

]

unique_branches = set(member_branches)

print()

print("Member branches list :", member_branches)

print("Unique branches set :", unique_branches)

print("How many branches :", len(unique_branches))

print("Tampines One present :", "Tampines One" in unique_branches)

print("Sentosa present :", "Sentosa" in unique_branches)

unique_branches.discard("JEM (Jurong East Mall)")

print("After discard :", unique_branches)


# ==================================================

# TASK 4 - WEEKLY TIMETABLE

# ==================================================

timetable = {

    "Mon": ["7:00 AM", "HIIT"],

    "Tue": ["6:00 PM", "Yoga"],

    "Wed": ["7:00 AM", "Spin"],

    "Thu": ["6:00 PM", "Pilates"],

    "Fri": ["7:00 AM", "HIIT"],

    "Sat": ["9:00 AM", "Strength Training"],

    "Sun": ["10:00 AM", "Yoga"]

}

print()

print("Timetable loaded :", timetable)

print("Wednesday slot :", timetable["Wed"])

print("Saturday time only :", timetable["Sat"][0])

timetable["Thu"] = ["7:00 PM", "Strength Training"]

print("Thursday slot :", timetable["Thu"])

print("All days :", timetable.keys())


# ==================================================

# TASK 5 - SORT BY NAME + FIND BY ID

# ==================================================

members_by_name = sorted(members, key=lambda m: m["name"])

print()

print("Members sorted by name:")

print(members_by_name[0]["name"])

print(members_by_name[1]["name"])

print(members_by_name[2]["name"])

print(members_by_name[3]["name"])

print(members_by_name[4]["name"])

print(members_by_name[5]["name"])

print(

    "Found FL-003:",

    members[2]["name"],

    "- plan:",

    members[2]["plan"]

)

print(

    "Found FL-005: branch:",

    members[4]["branch"]

)


# ==================================================

# FINAL STATUS

# ==================================================

# Re-create the complete set because JEM was discarded above

unique_branches = set(member_branches)

print()

print("-" * 60)

print(

    f"Loaded {len(members)} members, "

    f"{len(plans)} plans, "

    f"{len(unique_branches)} branches, "

    f"{len(timetable)} timetable days."

)

print("-" * 60)
# Out:
# Total members loaded : 6
# First member : {'id': 'FL-001', 'name': 'Tan Jia Hui', 'plan': 'Basic', 'branch': 'Tampines One', 'joined': '2025-10-15', 'expires': '2026-04-15', 'status': 'EXPIRED'}
# Third member's name : Nur Hidayah Binte Rahman
#
# Plans loaded : (('Basic', 88), ('Plus', 128), ('Premium', 188))
# First plan : ('Basic', 88)
# Last plan's fee : 188
#
# Member branches list : ['Tampines One', 'Bukit Timah Plaza', 'Tampines One', 'JEM (Jurong East Mall)', 'Bukit Timah Plaza', 'JEM (Jurong East Mall)']
# Unique branches set : {'JEM (Jurong East Mall)', 'Tampines One', 'Bukit Timah Plaza'}
# How many branches : 3
# Tampines One present : True
# Sentosa present : False
# After discard : {'Tampines One', 'Bukit Timah Plaza'}
#
# Timetable loaded : {'Mon': ['7:00 AM', 'HIIT'], 'Tue': ['6:00 PM', 'Yoga'], 'Wed': ['7:00 AM', 'Spin'], 'Thu': ['6:00 PM', 'Pilates'], 'Fri': ['7:00 AM', 'HIIT'], 'Sat': ['9:00 AM', 'Strength Training'], 'Sun': ['10:00 AM', 'Yoga']}
# ...
