# %% [markdown]
# <a href="https://colab.research.google.com/github/LiewWaiSan/Fitlife-Studio-Management-System/blob/main/Fitlife_M1_Liew_Wai_SanGH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Task 1: Create Studio Basic information
Task 2: Create Membership Plans
Task 3: Create Daily Promo Banner
Task 4: Capture a Walk-in

# %%
# -------------------------------
# TASK 1 - STUDIO BASICS
# -------------------------------

studio_name = "FitLife Studio"
founder = "Vincent Chua"
year_founded = 2019
headquarters = "Tampines One, Singapore"
total_branches = 3
total_members = 6
built_by = "Liew Wai San"

print("=" * 50)
print(f"{'Studio':<14} : {studio_name}")
print(f"{'Founder':<14} : {founder}")
print(f"{'Year founded':<14} : {year_founded}")
print(f"{'HQ':<14} : {headquarters}")
print(f"{'Branches':<14} : {total_branches}")
print(f"{'Members':<14} : {total_members}")
print(f"{'Built by':<14} : {built_by}")
print("=" * 50)


# -------------------------------
# TASK 2 - MEMBERSHIP PLANS
# -------------------------------

basic_plan = "Basic"
basic_fee = 88.00
basic_desc = "Gym access only (cardio + weights)"

plus_plan = "Plus"
plus_fee = 128.00
plus_desc = "Gym + 8 classes per month"

premium_plan = "Premium"
premium_fee = 188.00
premium_desc = "Gym + unlimited classes + sauna"

print()
print("--- MEMBERSHIP PLANS ---")
print("-" * 50)

print(f"{basic_plan:<10} | S${basic_fee:,.2f} | {basic_desc}")
print(f"{plus_plan:<10} | S${plus_fee:,.2f} | {plus_desc}")
print(f"{premium_plan:<10} | S${premium_fee:,.2f} | {premium_desc}")

print("-" * 50)
print("Starting from just S$" + f"{basic_fee:,.2f}" + " per month!")


# -------------------------------
# TASK 3 - DAILY PROMO
# -------------------------------

headline = "MAY MADNESS"
offer = "20% OFF your first 3 months"
promo_code = "MAY20"
valid_till = "31 May 2026"

print()
print(f"{'* ' * 3}{headline}{' *' * 3}")
print(offer)
print(f"Promo code: {promo_code}")
print(f"Valid till: {valid_till}")
print(f"Enter promo code {promo_code} at sign-up.")


# -------------------------------
# TASK 4 - WALK-IN CAPTURE
# -------------------------------

print()
name = input("Your name please: ")
age = int(input("Your age: "))

print("-" * 50)
print(f"Welcome, {name}! At {age} you're going to love our HIIT class.")
print("Powered by Python.")
# Out:
# ...
# Studio         : FitLife Studio
# Founder        : Vincent Chua
# Year founded   : 2019
# HQ             : Tampines One, Singapore
# Branches       : 3
# Members        : 6
# Built by       : Liew Wai San
# ...
#
# --- MEMBERSHIP PLANS ---
# --------------------------------------------------
# Basic      | S$88.00 | Gym access only (cardio + weights)
# Plus       | S$128.00 | Gym + 8 classes per month
# Premium    | S$188.00 | Gym + unlimited classes + sauna
# --------------------------------------------------
# Starting from just S$88.00 per month!
#
# * * * MAY MADNESS * * *
# 20% OFF your first 3 months
# Promo code: MAY20
# Valid till: 31 May 2026
# Enter promo code MAY20 at sign-up.
#
# Your name please: Clare
# Your age: 20
# --------------------------------------------------
# Welcome, Clare! At 20 you're going to love our HIIT class.
# Powered by Python.
